# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# Below clears JH previous downloads as they refine data daily

# %%
# !rm *-20*
# Out:
# rm: cannot remove '*-20*': No such file or directory

# %% [markdown]
# Update end date below to the previous day's date

# %%
x = pd.date_range(start='4/12/2020', end='9/10/2021')

# %%
for date_value in x.strftime('%m-%d-%Y'):
    url_value = r'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/' + date_value + r'.csv'
    # !wget $url_value
# Out:
# --2021-09-10 07:50:16--  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/04-12-2020.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7992 (7.8K) [text/plain]
# Saving to: ‘04-12-2020.csv’
#
# 04-12-2020.csv      100%[===================>]   7.80K  --.-KB/s    in 0.001s
#
# 2021-09-10 07:50:17 (5.95 MB/s) - ‘04-12-2020.csv’ saved [7992/7992]
#
# --2021-09-10 07:50:17--  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/04-13-2020.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# ...

# %%
df_jhu_us_dict= {}
for date_value in x.strftime('%m-%d-%Y'):
    df_jhu_us_dict[date_value] = pd.read_csv(date_value + r'.csv',header=0)

# %%
df_jhu_us_dict['09-07-2021'][df_jhu_us_dict['09-07-2021'].Province_State == 'Texas'].Confirmed
# Out:
# 49    3727663
# Name: Confirmed, dtype: int64

# %%
df_jhu_us_dict['09-07-2021'][df_jhu_us_dict['09-07-2021'].Province_State == 'Texas'].Confirmed - df_jhu_us_dict['09-06-2021'][df_jhu_us_dict['09-06-2021'].Province_State == 'Texas'].Confirmed
# Out:
# 49    19650
# Name: Confirmed, dtype: int64

# %%
len(x)
# Out:
# 516

# %%
date_list = []
for date_value in x.strftime('%m-%d-%Y'):
    date_list.append(date_value)

# %%
date_list
# Out:
# ['04-12-2020',
#  '04-13-2020',
#  '04-14-2020',
#  '04-15-2020',
#  '04-16-2020',
#  '04-17-2020',
#  '04-18-2020',
#  '04-19-2020',
#  '04-20-2020',
#  '04-21-2020',
#  '04-22-2020',
#  '04-23-2020',
#  '04-24-2020',
#  '04-25-2020',
#  '04-26-2020',
#  '04-27-2020',
#  '04-28-2020',
#  '04-29-2020',
#  '04-30-2020',
#  '05-01-2020',
#  '05-02-2020',
#  '05-03-2020',
#  '05-04-2020',
#  '05-05-2020',
#  '05-06-2020',
#  '05-07-2020',
#  '05-08-2020',
#  '05-09-2020',
#  '05-10-2020',
#  '05-11-2020',
#  '05-12-2020',
#  '05-13-2020',
#  '05-14-2020',
#  '05-15-2020',
#  '05-16-2020',
#  '05-17-2020',
#  '05-18-2020',
#  '05-19-2020',
#  '05-20-2020',
#  '05-21-2020',
#  '05-22-2020',
#  '05-23-2020',
#  '05-24-2020',
#  '05-25-2020',
#  '05-26-2020',
#  '05-27-2020',
#  '05-28-2020',
#  '05-29-2020',
#  '05-30-2020',
#  '05-31-2020',
#  '06-01-2020',
#  '06-02-2020',
#  '06-03-2020',
#  '06-04-2020',
#  '06-05-2020',
#  '06-06-2020',
#  '06-07-2020',
#  '06-08-2020',
# ...

# %%
for y in range(len(date_list) - 1):
    print(y)
    print(date_list[y])
# Out:
# 0
# 04-12-2020
# 1
# 04-13-2020
# 2
# 04-14-2020
# 3
# 04-15-2020
# 4
# 04-16-2020
# 5
# 04-17-2020
# 6
# 04-18-2020
# 7
# 04-19-2020
# 8
# 04-20-2020
# 9
# 04-21-2020
# 10
# 04-22-2020
# 11
# 04-23-2020
# 12
# 04-24-2020
# 13
# 04-25-2020
# 14
# 04-26-2020
# 15
# 04-27-2020
# 16
# 04-28-2020
# 17
# 04-29-2020
# 18
# 04-30-2020
# 19
# 05-01-2020
# 20
# 05-02-2020
# 21
# 05-03-2020
# 22
# 05-04-2020
# 23
# 05-05-2020
# 24
# 05-06-2020
# 25
# 05-07-2020
# 26
# 05-08-2020
# 27
# 05-09-2020
# 28
# 05-10-2020
# 29
# 05-11-2020
# 30
# 05-12-2020
# 31
# 05-13-2020
# 32
# 05-14-2020
# 33
# 05-15-2020
# 34
# 05-16-2020
# 35
# 05-17-2020
# 36
# 05-18-2020
# 37
# 05-19-2020
# 38
# 05-20-2020
# 39
# 05-21-2020
# 40
# 05-22-2020
# 41
# 05-23-2020
# 42
# 05-24-2020
# 43
# 05-25-2020
# 44
# 05-26-2020
# 45
# 05-27-2020
# 46
# 05-28-2020
# 47
# 05-29-2020
# 48
# 05-30-2020
# 49
# 05-31-2020
# 50
# 06-01-2020
# 51
# 06-02-2020
# 52
# 06-03-2020
# 53
# 06-04-2020
# 54
# 06-05-2020
# 55
# 06-06-2020
# ...

# %%
for y in range(len(date_list) - 1):
    print(date_list[y + 1])
    print(df_jhu_us_dict[date_list[y + 1]][df_jhu_us_dict[date_list[y + 1]].Province_State == 'Texas'].Confirmed - df_jhu_us_dict[date_list[y]][df_jhu_us_dict[date_list[y]].Province_State == 'Texas'].Confirmed)
# Out:
# 04-13-2020
# 47   NaN
# 49   NaN
# Name: Confirmed, dtype: float64
# 04-14-2020
# 49    760
# Name: Confirmed, dtype: int64
# 04-15-2020
# 49    956
# Name: Confirmed, dtype: int64
# 04-16-2020
# 49    941
# Name: Confirmed, dtype: int64
# 04-17-2020
# 49    940
# Name: Confirmed, dtype: int64
# 04-18-2020
# 49    799
# Name: Confirmed, dtype: int64
# 04-19-2020
# 49    558
# Name: Confirmed, dtype: int64
# 04-20-2020
# 49    565
# Name: Confirmed, dtype: int64
# 04-21-2020
# 49    938
# Name: Confirmed, dtype: int64
# 04-22-2020
# 49    792
# Name: Confirmed, dtype: int64
# 04-23-2020
# 49    1220
# Name: Confirmed, dtype: int64
# 04-24-2020
# 49    975
# Name: Confirmed, dtype: int64
# 04-25-2020
# 49    515
# Name: Confirmed, dtype: int64
# 04-26-2020
# 49    764
# Name: Confirmed, dtype: int64
# 04-27-2020
# 49    514
# Name: Confirmed, dtype: int64
# 04-28-2020
# 49    941
# Name: Confirmed, dtype: int64
# 04-29-2020
# 49    1036
# Name: Confirmed, dtype: int64
# 04-30-2020
# ...

# %%
for y in range(len(date_list) - 1):
    print(date_list[y + 1])
    print(df_jhu_us_dict[date_list[y + 1]][df_jhu_us_dict[date_list[y + 1]].Province_State.values == 'Texas'].Confirmed.values - df_jhu_us_dict[date_list[y]][df_jhu_us_dict[date_list[y]].Province_State == 'Texas'].Confirmed.values)
# Out:
# 04-13-2020
# [548]
# 04-14-2020
# [760]
# 04-15-2020
# [956]
# 04-16-2020
# [941]
# 04-17-2020
# [940]
# 04-18-2020
# [799]
# 04-19-2020
# [558]
# 04-20-2020
# [565]
# 04-21-2020
# [938]
# 04-22-2020
# [792]
# 04-23-2020
# [1220]
# 04-24-2020
# [975]
# 04-25-2020
# [515]
# 04-26-2020
# [764]
# 04-27-2020
# [514]
# 04-28-2020
# [941]
# 04-29-2020
# [1036]
# 04-30-2020
# [1348]
# 05-01-2020
# [1080]
# 05-02-2020
# [1156]
# 05-03-2020
# [997]
# 05-04-2020
# [766]
# 05-05-2020
# [1248]
# 05-06-2020
# [1088]
# 05-07-2020
# [1019]
# 05-08-2020
# [1286]
# 05-09-2020
# [1453]
# 05-10-2020
# [824]
# 05-11-2020
# [894]
# 05-12-2020
# [1329]
# 05-13-2020
# [1426]
# 05-14-2020
# [1245]
# 05-15-2020
# [1190]
# 05-16-2020
# [1759]
# 05-17-2020
# [980]
# 05-18-2020
# [770]
# 05-19-2020
# [1340]
# 05-20-2020
# [1245]
# 05-21-2020
# [1294]
# 05-22-2020
# [538]
# 05-23-2020
# [1115]
# 05-24-2020
# [1029]
# 05-25-2020
# [473]
# 05-26-2020
# [1034]
# 05-27-2020
# [1370]
# 05-28-2020
# [1787]
# ...
