# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import date, timedelta
import datetime
import matplotlib.dates as mdates
# %matplotlib inline
import pickle

# %% [markdown]
# https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u

# %%
# !ls -alt *
# Out:
# -rwxr-xr-x 1 ldhagen ldhagen 156196713 Jan  3 15:58  COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility_Latest.csv
# -rw-r--r-- 1 ldhagen ldhagen     83961 Jan  3 15:56  COVID_Hospital.ipynb
# -rwxr-xr-x 1 ldhagen ldhagen     88069 Jan  3 15:53 'COVID-19_Daily_Surveillance_Data_Public (4).csv'
# -rwxr-xr-x 1 ldhagen ldhagen     88069 Jan  3 15:08 'COVID-19_Daily_Surveillance_Data_Public (3).csv'
# -rw-r--r-- 1 ldhagen ldhagen  76778086 Jan  3 15:05 'rows.csv?accessType=DOWNLOAD'
# -rw-r--r-- 1 ldhagen ldhagen    652089 Jan  3 14:03  UltraSlim.ipynb
# -rw-r--r-- 1 ldhagen ldhagen     45759 Jan  3 14:01 'JHUDaily Travis, Texas, US New.png'
# -rw-r--r-- 1 ldhagen ldhagen     47574 Jan  3 14:01 'JHUDaily Harris, Texas, US New.png'
# -rw-r--r-- 1 ldhagen ldhagen     54440 Jan  3 14:01 'JHUDaily Dallas, Texas, US New.png'
# -rw-r--r-- 1 ldhagen ldhagen     46731 Jan  3 14:01 'JHUDaily Bexar, Texas, US New.png'
# ...

# %%
df_covid_hospital = pd.read_csv('COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility_Latest.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_covid_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369758 entries, 0 to 369757
# Columns: 106 entries, hospital_pk to is_corrected
# dtypes: bool(2), float64(71), int64(23), object(10)
# memory usage: 294.1+ MB

# %%
df_covid_hospital.tail(10)
# Out:
#        hospital_pk collection_week state     ccn  \
# 369748      461301       7/31/2020    UT  461301
# 369749      301309       7/31/2020    NH  301309
# 369750      451370       7/31/2020    TX  451370
# 369751      130071       7/31/2020    ID  130071
# 369752      160122       7/31/2020    IA  160122
# 369753      210005       7/31/2020    MD  210005
# 369754      420053       7/31/2020    SC  420053
# 369755      400122       7/31/2020    PR  400122
# 369756      110194       7/31/2020    GA  110194
# 369757      330385       7/31/2020    NY  330385
#
#                              hospital_name  \
# 369748         FILLMORE COMMUNITY HOSPITAL
# 369749        MONADNOCK COMMUNITY HOSPITAL
# 369750                TMC- BONHAM HOSPITAL
# 369751      ST LUKE'S NAMPA MEDICAL CENTER
# 369752     FORT MADISON COMMUNITY HOSPITAL
# 369753           FREDERICK HEALTH HOSPITAL
# 369754   NEWBERRY COUNTY MEMORIAL HOSPITAL
# 369755  PROFESSIONAL HOSPITAL GUAYNABO INC
# ...

# %%
df_covid_hospital[df_covid_hospital.total_personnel_covid_vaccinated_doses_none_7_day == 2230.0]
# Out:
#        hospital_pk collection_week state     ccn  \
# 5103        330046      12/17/2021    NY  330046
# 83248       230195       9/10/2021    MI  230195
# 118315      340032       7/16/2021    NC  340032
# 137883      450213       6/18/2021    TX  450213
# 210111      310012       2/26/2021    NJ  310012
#
#                                       hospital_name  \
# 5103                               MOUNT SINAI WEST
# 83248   ASCENSION MACOMB OAKLAND HOSP-WARREN CAMPUS
# 118315             CAROMONT REGIONAL MEDICAL CENTER
# 137883                     UNIVERSITY HEALTH SYSTEM
# 210111                              VALLEY HOSPITAL
#
#                             address         city      zip hospital_subtype  \
# 5103              1000 TENTH AVENUE     NEW YORK  10019.0       Short Term
# 83248   11800 EAST TWELVE MILE ROAD       WARREN  48093.0       Short Term
# 118315                2525 COURT DR     GASTONIA  28052.0       Short Term
# ...

# %%
df_covid_hospital[df_covid_hospital.address == '4502 MEDICAL DR'].head()
# Out:
#       hospital_pk collection_week state     ccn             hospital_name  \
# 2151       450213      12/24/2021    TX  450213  UNIVERSITY HEALTH SYSTEM
# 13225      450213      12/17/2021    TX  450213  UNIVERSITY HEALTH SYSTEM
# 18600      450213      12/10/2021    TX  450213  UNIVERSITY HEALTH SYSTEM
# 19577      450213       12/3/2021    TX  450213  UNIVERSITY HEALTH SYSTEM
# 21459      450213      11/26/2021    TX  450213  UNIVERSITY HEALTH SYSTEM
#
#                address         city      zip hospital_subtype  fips_code  \
# 2151   4502 MEDICAL DR  SAN ANTONIO  78229.0       Short Term    48029.0
# 13225  4502 MEDICAL DR  SAN ANTONIO  78229.0       Short Term    48029.0
# 18600  4502 MEDICAL DR  SAN ANTONIO  78229.0       Short Term    48029.0
# 19577  4502 MEDICAL DR  SAN ANTONIO  78229.0       Short Term    48029.0
# 21459  4502 MEDICAL DR  SAN ANTONIO  78229.0       Short Term    48029.0
#
#        is_metro_micro  total_beds_7_day_avg  \
# ...

# %%
df_covid_hospital[df_covid_hospital.city == 'SAN ANTONIO'][['hospital_name']]
# Out:
#                                             hospital_name
# 102           FOUNDATION SURGICAL HOSPITAL OF SAN ANTONIO
# 582           BAPTIST NEIGHBORHOOD HOSPITAL THOUSAND OAKS
# 739                          KINDRED HOSPITAL SAN ANTONIO
# 813                 PAM SPECIALTY HOSPITAL OF SAN ANTONIO
# 981                          KINDRED HOSPITAL SAN ANTONIO
# 1787                            LEGENT ORTHOPEDIC + SPINE
# 2151                             UNIVERSITY HEALTH SYSTEM
# 2189                            LEGENT ORTHOPEDIC + SPINE
# 2926          BAPTIST NEIGHBORHOOD HOSPITAL THOUSAND OAKS
# 2957                   CHRISTUS SANTA ROSA MEDICAL CENTER
# 3636          FOUNDATION SURGICAL HOSPITAL OF SAN ANTONIO
# 3800                   CHILDREN'S HOSPITAL OF SAN ANTONIO
# 3946                KINDRED HOSPITAL- SAN ANTONIO CENTRAL
# 4165          FOUNDATION SURGICAL HOSPITAL OF SAN ANTONIO
# 4766              SOUTH TEXAS SPINE AND SURGICAL HOSPITAL
# ...

# %%
df_covid_hospital.shape
# Out:
# (369758, 106)

# %%
df_covid_hospital.sort_values(by ='collection_week', ascending = True).tail()
# Out:
#                                               hospital_pk collection_week  \
# 335790                                             100179        9/4/2020
# 350792                                             520095        9/4/2020
# 335787                                              50760        9/4/2020
# 350806                                             451306        9/4/2020
# 340011  ff9032c172057190bf52f523d253c79af2d5f74d007084...        9/4/2020
#
#        state     ccn                         hospital_name  \
# 335790    FL  100179        MEMORIAL HOSPITAL JACKSONVILLE
# 350792    WI  520095                 SAUK PRAIRIE HOSPITAL
# 335787    CA   50760  KAISER FOUNDATION HOSPITAL - ANTIOCH
# 350806    TX  451306                       KIMBLE HOSPITAL
# 340011    PR     NaN                          HealthproMed
#
#                        address            city      zip  \
# 335790  3625 UNIVERSITY BLVD S    JACKSONVILLE  32216.0
# ...

# %%
type(df_covid_hospital.collection_week)
# Out:
# pandas.core.series.Series
