# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import date, timedelta
import datetime
import matplotlib.dates as mdates
# %matplotlib inline
import pickle

# %% [markdown]
# https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/anag-cw7u

# %%
# !ls -alt *
# Out:
# -rw-r--r-- 1 ldhagen ldhagen 320934031 Dec 31 14:45  30_Dec_2021_JHU_total_data.pkl
# -rwxrwxrwx 1 ldhagen ldhagen 154201145 Dec 31 14:39  COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv
# -rw-r--r-- 1 ldhagen ldhagen     63489 Dec 31 14:28  COVID_Hospital.ipynb
# -rw-r--r-- 1 ldhagen ldhagen    472116 Dec 31 14:16  UltraSlim.ipynb
# -rw-r--r-- 1 ldhagen ldhagen   3208096 Dec 30 17:24  JHU_Each_State_New_Cases.ipynb
# -rw-r--r-- 1 ldhagen ldhagen     40101 Dec 30 17:22 'JHUDaily Florida New.png'
# -rw-r--r-- 1 ldhagen ldhagen     42773 Dec 30 17:22 'JHUDaily Hawaii New.png'
# -rw-r--r-- 1 ldhagen ldhagen     53031 Dec 30 17:22 'JHUDaily Pennsylvania New.png'
# -rw-r--r-- 1 ldhagen ldhagen     39623 Dec 30 17:22 'JHUDaily Illinois New.png'
# -rw-r--r-- 1 ldhagen ldhagen     42305 Dec 30 17:22 'JHUDaily New Jersey New.png'
# -rw-r--r-- 1 ldhagen ldhagen     42619 Dec 30 17:22 'JHUDaily New York New.png'
# ...

# %%
df_covid_hospital = pd.read_csv('COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_Facility.csv')

# %%
df_covid_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364751 entries, 0 to 364750
# Columns: 106 entries, hospital_pk to is_corrected
# dtypes: bool(2), float64(71), int64(23), object(10)
# memory usage: 290.1+ MB

# %%
df_covid_hospital.head()
# Out:
#   hospital_pk collection_week state     ccn  \
# 0      670143      2021/12/17    TX  670143
# 1      650003      2021/12/17    GU  650003
# 2      250152      2021/12/10    MS  250152
# 3      433300      2021/12/10    SD  433300
# 4      430091      2021/12/10    SD  430091
#
#                        hospital_name                   address         city  \
# 0            ASCENSION SETON BASTROP          630 HIGWAY 71 W,      BASTROP
# 1         GUAM REGIONAL MEDICAL CITY               133 ROUTE 3       DEDEDO
# 2    MISSISSIPPI METHODIST REHAB CTR  1350 E WOODROW WILSON DR      JACKSON
# 3                          LIFESCAPE            2501 W 26TH ST  SIOUX FALLS
# 4  BLACK HILLS SURGICAL HOSPITAL LLP           216 ANAMARIA DR   RAPID CITY
#
#        zip     hospital_subtype  fips_code  ...  \
# 0  78602.0           Short Term    48021.0  ...
# 1  96929.0           Short Term    66010.0  ...
# 2  39216.0           Short Term    28049.0  ...
# ...

# %%
df_covid_hospital[df_covid_hospital.total_personnel_covid_vaccinated_doses_none_7_day == 2230.0]
# Out:
#        hospital_pk collection_week state     ccn  \
# 4787        330046      2021/12/17    NY  330046
# 65672       230195      2021/09/10    MI  230195
# 107992      340032      2021/07/16    NC  340032
# 137506      450213      2021/06/18    TX  450213
# 217997      310012      2021/02/26    NJ  310012
#
#                                       hospital_name  \
# 4787                               MOUNT SINAI WEST
# 65672   ASCENSION MACOMB OAKLAND HOSP-WARREN CAMPUS
# 107992             CAROMONT REGIONAL MEDICAL CENTER
# 137506                     UNIVERSITY HEALTH SYSTEM
# 217997                              VALLEY HOSPITAL
#
#                             address         city      zip hospital_subtype  \
# 4787              1000 TENTH AVENUE     NEW YORK  10019.0       Short Term
# 65672   11800 EAST TWELVE MILE ROAD       WARREN  48093.0       Short Term
# 107992                2525 COURT DR     GASTONIA  28052.0       Short Term
# ...

# %%
df_covid_hospital[df_covid_hospital.address == '4502 MEDICAL DR']
# Out:
#        hospital_pk collection_week state     ccn             hospital_name  \
# 4779        450213      2021/12/17    TX  450213  UNIVERSITY HEALTH SYSTEM
# 6202        450213      2021/12/10    TX  450213  UNIVERSITY HEALTH SYSTEM
# 14399       450213      2021/11/19    TX  450213  UNIVERSITY HEALTH SYSTEM
# 17073       450213      2021/12/03    TX  450213  UNIVERSITY HEALTH SYSTEM
# 22276       450213      2021/11/26    TX  450213  UNIVERSITY HEALTH SYSTEM
# ...            ...             ...   ...     ...                       ...
# 347107      450213      2020/08/28    TX  450213  UNIVERSITY HEALTH SYSTEM
# 349622      450213      2020/08/21    TX  450213  UNIVERSITY HEALTH SYSTEM
# 354955      450213      2020/07/31    TX  450213  UNIVERSITY HEALTH SYSTEM
# 360258      450213      2020/08/07    TX  450213  UNIVERSITY HEALTH SYSTEM
# 361604      450213      2020/08/14    TX  450213  UNIVERSITY HEALTH SYSTEM
#
# ...
